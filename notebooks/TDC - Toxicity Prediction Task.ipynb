# %%
import os
import pandas as pd
import numpy as np
import time
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import logging
from glob import glob
import pubchempy as pcp
from rdkit import Chem
from rdkit.Chem import rdMolDescriptors, Draw

import tdc
from tdc.single_pred import Tox
from ersilia import ErsiliaModel

from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold, StratifiedKFold, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix, precision_recall_curve, roc_curve
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.combine import SMOTEENN
from sklearn.utils.class_weight import compute_class_weight
import xgboost as xgb

from scripts.data_loader import DataDownloader
from scripts.data_processor import DataProcessor
from scripts.explore import ExploratoryDataAnalysis
from scripts.featurize import Featurizer

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# ### **Getting to Know Our Data**

# %%
dataset_name = "hERG"
downloader = DataDownloader()
df, splits = None, None

# %%
download = 'Y'
# download = input("Use Existing Data? (Y/N): ").strip().upper(). Uncomment this line to interact

# %%
if download == 'N':
    print("\nDownloading data...")
    df, splits = downloader.fetch_dataset(name = dataset_name)
else:
    print("\nLoading existing data...")
    try:
        df = pd.read_csv(f'../data/{dataset_name}/{dataset_name}.csv')
        train = pd.read_csv(f'../data/{dataset_name}/train.csv') 
        validation = pd.read_csv(f'../data/{dataset_name}/validation.csv') 
        test = pd.read_csv(f'../data/{dataset_name}/test.csv') 
        splits = {"train": train, "validation": validation, "test": test}
        print("Data successfully loaded.")
    except FileNotFoundError as e:
        print(f"Error: {e}. Dataset not found, attempting to download...")
        df, splits = downloader.fetch_dataset(name = dataset_name)
# Out:
# Loading existing data...
# Data successfully loaded.

# %%
files_to_preprocess = [f"../data/{dataset_name}/{key}.csv" for key in splits.keys()]
files_to_preprocess
# Out:
# ['../data/hERG/train.csv',
#  '../data/hERG/validation.csv',
#  '../data/hERG/test.csv']

# %%
np.median([len(drug) for drug in df.Drug])
# Out:
# 50.0

# %%
for file in files_to_preprocess:
    processor = DataProcessor(input_csv = file, output_csv = file)
    processor.process_csv()
# Out:
# 2025-03-31 07:28:53,823 - INFO - No missing Drug_IDs found. No processing needed.
# 2025-03-31 07:28:53,829 - INFO - No missing Drug_IDs found. No processing needed.
# 2025-03-31 07:28:53,829 - INFO - No missing Drug_IDs found. No processing needed.
# 2025-03-31 07:28:53,840 - INFO - No missing Drug_IDs found. No processing needed.
# 2025-03-31 07:28:53,840 - INFO - No missing Drug_IDs found. No processing needed.
# 2025-03-31 07:28:53,840 - INFO - No missing Drug_IDs found. No processing needed.

# %%
train.head()
# Out:
#                 Drug_ID                                               Drug    Y
# 0           DELAVIRDINE  CC(C)Nc1cccnc1N1CCN(C(=O)C2=CC3=C[C@H](NS(C)(=... 0.00
# 1          SOPHOCARPINE    O=C1C=CC[C@@H]2[C@H]3CCCN4CCC[C@H](CN12)[C@H]34 0.00
# 2            RALOXIFENE  O=C(c1ccc(OCC[NH+]2CCCCC2)cc1)c1c(-c2ccc(O)cc2... 0.00
# 3  N-DEMETHYLOLANZAPINE                   Cc1cc2c(s1)Nc1ccccc1N=C2N1CCNCC1 1.00
# 4             SUNITINIB  CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F... 1.00

# %% [markdown]
# #### **Brief EDA**

# %%
explore = ExploratoryDataAnalysis(dataset_name)
explore.generate_eda()
# Out:
# 2025-03-31 07:28:53,926 - INFO - Absolute data path: /home/gentroyal/outreachy-temp/data/hERG/hERG.csv
# 2025-03-31 07:28:53,929 - INFO - Absolute figure directory: /home/gentroyal/outreachy-temp/data/figures/hERG
# 2025-03-31 07:28:53,939 - INFO - Figure directory verified at: /home/gentroyal/outreachy-temp/data/figures/hERG
# 2025-03-31 07:28:53,945 - INFO - 451 drugs are classified as blockers
# 2025-03-31 07:28:53,947 - INFO - 204 drugs are classified as non-blockers
# 2025-03-31 07:28:54,319 - INFO - Saved figure to: /home/gentroyal/outreachy-temp/data/figures/hERG/label_distribution.png
# 2025-03-31 07:28:54,831 - INFO - Saved figure to: /home/gentroyal/outreachy-temp/data/figures/hERG/smiles_length.png
# 2025-03-31 07:28:54,833 - INFO - EDA for hERG completed successfully.

# %% [markdown]
# **Comment:** There are 451 blockers (classed as 1) and and 204 nonblockers (classed as 0). Since there is a huge difference in the number of samples in both classes, it means that there is an imbalance and we need to address this before we can train our machine learning model.

# %%
smiles_list = df["Drug"].iloc[:3].tolist()  # First 3 SMILES
drug_names = df["Drug_ID"].iloc[:3].tolist()  # Their  Names

mols = [Chem.MolFromSmiles(smiles) for smiles in smiles_list]
Draw.MolsToGridImage(mols, molsPerRow = 3, subImgSize=(300, 300), legends=drug_names)

# %% [markdown]
# **Comment:**

# %%
model_name = "eos5guo"
# !ersilia fetch $model_name #Uncomment this line if model has not been fetched
# Out:
# ⬇️  Fetching model eos5guo: erg-descs
# sudo: unknown user udockerusername
# sudo: error initializing audit plugin sudoers_audit
# 👎 Model eos5guo failed to fetch! Model already exists on your system. If you want to fetch it again, please delete the existing model first.

# %% [markdown]
# ### **Featurizer**

# %%
count = len(glob(f"../data/{dataset_name}/*{model_name}_featurized*"))
files = ['train', 'test', 'validation']

print("\nPerforming Featurisation...")
if count == 0:
    featurizer = Featurizer(model_id = model_name)
    
    for file in files:
        output_path = featurizer.featurize(input_file = file, dataset_name = dataset_name)
else:
    print("\nData has already by Featurised...")
# Out:
# Performing Featurisation...
#
# Data has already by Featurised...

# %% [markdown]
# ### Building a ML Model

# %% [markdown]
# #### Loading Data for Preprocessing

# %%
def load_featurised_dataset(model_name):
    featurised_partition = [f"../data/{dataset_name}/{key}_{model_name}_featurized.csv" for key in splits.keys()]
    train = pd.read_csv(featurised_partition[0])
    train.drop(columns = ['key', 'input'], inplace = True)
    validation = pd.read_csv(featurised_partition[1])
    validation.drop(columns = ['key', 'input'], inplace = True)
    test = pd.read_csv(featurised_partition[2])
    test.drop(columns = ['key', 'input'], inplace = True)

    return train, validation, test

# %%
def prepare_features_and_target(df, target = 'Y'):
    X = df.drop(columns = [target])
    y = df[target]

    if model_name == 'eos24ci':
        new_cols = X.columns.tolist()
        xters = [chr(char) for char in range(ord('a'), ord('z') + 1)][:10]
        
        for i, (char, col) in enumerate(zip(X.columns[-10:], xters)):
            new_cols[-10 + i] = char[:-1] + col  # Replace only the last character
        
        X.columns = new_cols
        
    nan_rows = X.isna().sum(axis=1) > 0
    X = X[(X != 0).any(axis = 1) & X.notna().any(axis = 1)]
    y = y.loc[X.index]
    
    df = X.merge(y, left_on = X.index, right_on = y.index, how = 'inner').drop(columns = ['key_0'])
    
    return df

# %%
def get_scaled_set(train, test, val, target = 'Y'):
    X_train, y_train = train.drop(columns = [target]), train[target]    
    X_test, y_test = test.drop(columns = [target]), test[target]
    X_val, y_val = val.drop(columns = [target]), val[target]

    zero_columns = X_train.columns[(X_train.nunique() == 1)]
    X_train.drop(columns = zero_columns, inplace = True)
    X_test.drop(columns = zero_columns, inplace = True)
    X_val.drop(columns = zero_columns, inplace = True)

    scalar = StandardScaler()
    X_train_scaled = scalar.fit_transform(X_train)
    X_test_scaled = scalar.transform(X_test)
    X_val_scaled = scalar.transform(X_val)

    return X_train_scaled, y_train, X_test_scaled, y_test, X_val_scaled, y_val

# %% [markdown]
# #### Addressing Imbalance

# %%
def preprocess_and_resample(model_name, target='Y'):
    # Load dataset
    train, validation, test = load_featurised_dataset(model_name)
    
    # Prepare features and target
    train = prepare_features_and_target(train, target=target)
    test = prepare_features_and_target(test, target=target)
    val = prepare_features_and_target(validation, target=target)
    
    # Scale dataset
    X_train, y_train, X_test, y_test, X_val, y_val = get_scaled_set(train, test, val, target=target)
    
    # SMOTE (Oversampling)
    smote = SMOTE(random_state=42)
    X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)
    
    # Random Oversampling
    oversampler = RandomOverSampler(random_state=42)
    X_train_over, y_train_over = oversampler.fit_resample(X_train, y_train)
    
    # Hybrid (SMOTE + ENN)
    smote_enn = SMOTEENN(random_state=42)
    X_train_hybrid, y_train_hybrid = smote_enn.fit_resample(X_train, y_train)
    
    return (X_train, y_train, 
            X_test, y_test, 
            X_val, y_val, 
            X_train_smote, y_train_smote, 
            X_train_over, y_train_over, 
            X_train_hybrid, y_train_hybrid
           )

# %% [markdown]
# #### RandomForestClassifier

# %%
def train_randomforest_cv(X_train, y_train, X_test, y_test, X_val, y_val, class_weight, 
                       use_stratified_kfold=False, use_gridsearch=False):
    
    # Base hyperparameters
    rf_params = {
        "n_estimators": 200,
        "criterion": "gini",
        "min_samples_split": 5,
        "min_samples_leaf": 5,
        "max_features": "sqrt",
        "random_state": 42,
        "n_jobs": -1,
    }


    class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weight_dict = {0: class_weights[0], 1: class_weights[1]}

    # Adjust max_depth and class_weight
    rf_params["max_depth"] = 4 if class_weight else 3
    if class_weight:
        rf_params["class_weight"] = class_weight_dict

    # Initialize the classifier
    rf = RandomForestClassifier(**rf_params)

    # Grid Search for Hyperparameter Tuning
    if use_gridsearch:
        param_grid = {
            "n_estimators": [100, 200, 300],
            "max_depth": [5],
            "min_samples_split": [2, 5, 10],
            "min_samples_leaf": [1, 5, 10],
            "max_features": ["sqrt", "log2"]
        }

        grid_search = GridSearchCV(rf, param_grid, cv = 5, scoring="roc_auc", n_jobs=-1, verbose=1)
        grid_search.fit(X_train, y_train)
        rf = grid_search.best_estimator_
        print("\nBest Parameters from GridSearchCV:", grid_search.best_params_)

    # KFold or StratifiedKFold Cross-Validation
    if use_stratified_kfold:
        cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
        cv_scores = []

        for train_idx, val_idx in cv.split(X_train, y_train):
            X_t, X_v = X_train[train_idx], X_train[val_idx]
            y_t, y_v = y_train[train_idx], y_train[val_idx]

            rf.fit(X_t, y_t)
            y_pred_v = rf.predict(X_v)
            cv_scores.append(roc_auc_score(y_v, y_pred_v))

        print("\nCross-Validation ROC AUC Scores:", cv_scores)
        print("Mean ROC AUC:", sum(cv_scores) / len(cv_scores))

    # Train final model on full training data
    rf.fit(X_train, y_train)
    
    def compute_metrics(y_true, y_pred, y_proba, dataset_name):
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        precision = tp / (tp + fp) if (tp + fp) != 0 else 0
        recall = tp / (tp + fn) if (tp + fn) != 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) != 0 else 0
        roc_auc = roc_auc_score(y_true, y_proba)

        # Print results inside the function
        print("=" * 50)
        print(f"{dataset_name} Metrics:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1_score:.4f}")
        print(f"ROC AUC: {roc_auc:.4f}")
        print("=" * 50)

        return {
            "confusion_matrix": (tn, fp, fn, tp),
            "accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "f1_score": f1_score,
            "roc_auc": roc_auc
        }

    # Compute metrics for Train, Validation, and Test sets
    y_train_pred = rf.predict(X_train)
    y_train_proba = rf.predict_proba(X_train)[:, 1]
    train_metrics = compute_metrics(y_train, y_train_pred, y_train_proba, "Train")

    y_val_pred = rf.predict(X_val)
    y_val_proba = rf.predict_proba(X_val)[:, 1]
    val_metrics = compute_metrics(y_val, y_val_pred, y_val_proba, "Validation")

    y_test_pred = rf.predict(X_test)
    y_test_proba = rf.predict_proba(X_test)[:, 1]
    test_metrics = compute_metrics(y_test, y_test_pred, y_test_proba, "Test") 
    
    # Precision-Recall curve
    precision_curve, recall_curve, _ = precision_recall_curve(y_test, y_test_proba)
    
    # ROC Curve
    fpr, tpr, _ = roc_curve(y_test, y_test_proba)

    return rf, {
        "train_metrics": train_metrics,
        "val_metrics": val_metrics,
        "test_metrics": test_metrics,
        "y_train_pred": y_train_pred,
        "y_train_proba": y_train_proba,
        "y_val_pred": y_val_pred,
        "y_val_proba": y_val_proba,
        "y_test_pred": y_test_pred,
        "y_test_proba": y_test_proba,
        "precision_curve" : precision_curve, 
        "recall_curve" : recall_curve
    }

# %% [markdown]
# #### XGBoost Classifier

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report, roc_auc_score

def train_xgboost_cv(X_train, y_train, X_test, y_test, X_val, y_val, class_weight=None, 
                      use_stratified_kfold=False, use_gridsearch=False):
    
    # Base hyperparameters
    xgb_params = {
        "n_estimators": 200,
        "learning_rate": 0.1,
        "max_depth": 4 if class_weight else 3,
        "min_child_weight": 5,
        "subsample": 0.8,
        "colsample_bytree": 0.8,
        "random_state": 42,
        "n_jobs": -1,
        "eval_metric": "logloss"
    }
    
    if class_weight:
        xgb_params["scale_pos_weight"] = sum(y_train == 0) / sum(y_train == 1) 
    
    xgb = XGBClassifier(**xgb_params)
    
    if use_gridsearch:
        param_grid = {
            "n_estimators": [100, 200, 300],
            "max_depth": [3, 5],
            "learning_rate": [0.01],
            "min_child_weight": [1, 5, 10],
            "subsample": [0.8],
            "colsample_bytree": [0.8, 1.0]
        }
        
        grid_search = GridSearchCV(xgb, param_grid, cv=5, scoring="roc_auc", n_jobs=-1, verbose=1)
        grid_search.fit(X_train, y_train)
        xgb = grid_search.best_estimator_
        print("\nBest Parameters from GridSearchCV:", grid_search.best_params_)
    
    # StratifiedKFold Cross-Validation
    if use_stratified_kfold:
        cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
        cv_scores = []
        
        for train_idx, val_idx in cv.split(X_train, y_train):
            X_t, X_v = X_train[train_idx], X_train[val_idx]
            y_t, y_v = y_train[train_idx], y_train[val_idx]
            
            xgb.fit(X_t, y_t)
            y_pred_v = xgb.predict(X_v)
            cv_scores.append(roc_auc_score(y_v, y_pred_v))
        
        print("\nCross-Validation ROC AUC Scores:", cv_scores)
        print("Mean ROC AUC:", sum(cv_scores) / len(cv_scores))
    
    # Train final model on full training data
    xgb.fit(X_train, y_train)
    
    def compute_metrics(y_true, y_pred, y_proba, dataset_name):
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        precision = tp / (tp + fp) if (tp + fp) != 0 else 0
        recall = tp / (tp + fn) if (tp + fn) != 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) != 0 else 0
        roc_auc = roc_auc_score(y_true, y_proba)

        # Print results inside the function
        print("=" * 50)
        print(f"{dataset_name} Metrics:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1_score:.4f}")
        print(f"ROC AUC: {roc_auc:.4f}")
        print("=" * 50)

        return {
            "confusion_matrix": (tn, fp, fn, tp),
            "accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "f1_score": f1_score,
            "roc_auc": roc_auc
        }

    # Compute metrics for Train, Validation, and Test sets
    y_train_pred = xgb.predict(X_train)
    y_train_proba = xgb.predict_proba(X_train)[:, 1]
    train_metrics = compute_metrics(y_train, y_train_pred, y_train_proba, "Train")

    y_val_pred = xgb.predict(X_val)
    y_val_proba = xgb.predict_proba(X_val)[:, 1]
    val_metrics = compute_metrics(y_val, y_val_pred, y_val_proba, "Validation")

    y_test_pred = xgb.predict(X_test)
    y_test_proba = xgb.predict_proba(X_test)[:, 1]
    test_metrics = compute_metrics(y_test, y_test_pred, y_test_proba, "Test") 
    
    # Precision-Recall curve
    precision_curve, recall_curve, _ = precision_recall_curve(y_test, y_test_proba)
    
    # ROC Curve
    fpr, tpr, _ = roc_curve(y_test, y_test_proba)

    return xgb, {
        "train_metrics": train_metrics,
        "val_metrics": val_metrics,
        "test_metrics": test_metrics,
        "y_train_pred": y_train_pred,
        "y_train_proba": y_train_proba,
        "y_val_pred": y_val_pred,
        "y_val_proba": y_val_proba,
        "y_test_pred": y_test_pred,
        "y_test_proba": y_test_proba,
        "precision_curve" : precision_curve,
        "recall_curve" : recall_curve
        
    }

# %% [markdown]
# #### Model Evaluation

# %%
def evaluate_model(model_results, graph_title, Featurizer = model_name):
    best_model = None
    best_roc_auc = 0

    save_path = f"../data/figures/{dataset_name}/"
        
    for model, results in model_results.items():
        roc_score = results['test_metrics']['roc_auc']
        
        if roc_score > best_roc_auc:
            best_roc_auc = roc_score
            best_model = model
            best_results = results
    
    
    print("Best Model:", best_model)
    print("Best ROC-Score:", best_roc_auc)
    
    fpr, tpr, _ = roc_curve(y_test, best_results["y_test_proba"])
    
    plt.figure(figsize=(6, 4))
    plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {best_roc_auc:.4f})")
    plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"ROC Curve: {graph_title} - {Featurizer}")
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join(save_path, f"ROC Curve- {graph_title} - {Featurizer}.png"))
    plt.show()
    
    precision_curve = best_results["precision_curve"]
    recall_curve = best_results["recall_curve"]
    
    plt.figure(figsize=(6, 4))
    plt.plot(recall_curve, precision_curve, label="Precision-Recall Curve")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title(f"Precision-Recall Curve: {graph_title} - {Featurizer}")
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join(save_path, f"Precision-Recall Curve- {graph_title} - {Featurizer}.png"))
    plt.show()
    
    y_test_pred = best_results["y_test_pred"]
    cm = confusion_matrix(y_test, y_test_pred)
    TN, FP, FN, TP = cm.ravel()

    specificity = TN / (TN + FP)
    npv = TN / (TN + FN) 
    
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["No Blockage", "Blockage"], yticklabels=["No Blockage", "Blockage"])
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title(f"Confusion Matrix: {graph_title} - {Featurizer}\nSpecificity: {specificity:.2%}, NPV: {npv:.2%}")
    plt.grid(True)
    # Save the figure
    plt.savefig(os.path.join(save_path, f"Confusion Matrix: {graph_title} - {Featurizer}"))
    plt.show()


    if hasattr(best_model, "feature_importances_"):
        feature_importances = best_model.feature_importances_
        feature_names = [f"Feature {i}" for i in range(len(feature_importances))]
        
        sorted_indices = np.argsort(feature_importances)[-10:]
        top_features = np.array(feature_names)[sorted_indices]
        top_importances = feature_importances[sorted_indices]
        
        plt.figure(figsize=(10, 5))
        sns.barplot(x=top_features, y=top_importances)
        plt.xlabel("Features")
        plt.ylabel("Feature Importance")
        plt.title(f"Top 10 Feature Importances: {graph_title} - {Featurizer}")
        plt.xticks(rotation = 45)
        plt.grid(True)
        plt.savefig(os.path.join(save_path, f"Top 10 Feature Importances: {graph_title} - {Featurizer}"))
        plt.show()

# %% [markdown]
# #### Model Configuration

# %%
def model_config():
    train_sets = {
        "Original Set": (X_train, y_train),
        "Oversampled": (X_train_over, y_train_over),
        "SMOTE": (X_train_smote, y_train_smote),
        "Hybrid": (X_train_hybrid, y_train_hybrid),
        }
        
    configs = [
        {"class_weight": False, "use_stratified_kfold": False, "use_gridsearch": False},
        {"class_weight": True, "use_stratified_kfold": False, "use_gridsearch": False},
        {"class_weight": True, "use_stratified_kfold": True, "use_gridsearch": False},
        {"class_weight": True, "use_stratified_kfold": False, "use_gridsearch": True},
        {"class_weight": False, "use_stratified_kfold": True, "use_gridsearch": False},
        {"class_weight": False, "use_stratified_kfold": False, "use_gridsearch": True},
        ]

    return train_sets, configs

# %% [markdown]
# #### Modelling (ERG 2D Featuriser)

# %%
model_name = 'eos5guo'  
(X_train, y_train, 
            X_test, y_test, 
            X_val, y_val, 
            X_train_smote, y_train_smote, 
            X_train_over, y_train_over, 
            X_train_hybrid, y_train_hybrid)= preprocess_and_resample(model_name)

train_sets, configs = model_config()

# %%
# Train on RandomForest
erg2d_model_results = {}
for train_set_name, (X_train_set, y_train_set) in train_sets.items():
    print(train_set_name)
    for config in configs:
        print(config.items())
        erg2d_model, erg2d_model_result = train_randomforest_cv(
            X_train_set, y_train_set, X_test, y_test, X_val, y_val,
            class_weight=config["class_weight"],
            use_stratified_kfold=config["use_stratified_kfold"],
            use_gridsearch=config["use_gridsearch"]
        )
        erg2d_model_results[erg2d_model] = erg2d_model_result
    print()
# Out:
# Original Set
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.7944
# Precision: 0.7740
# Recall: 0.9906
# F1 Score: 0.8690
# ROC AUC: 0.8953
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7015
# Precision: 0.6833
# Recall: 0.9762
# F1 Score: 0.8039
# ROC AUC: 0.8233
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7714
# Precision: 0.7612
# Recall: 1.0000
# F1 Score: 0.8644
# ROC AUC: 0.7842
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.8420
# Precision: 0.9125
# Recall: 0.8522
# F1 Score: 0.8813
# ROC AUC: 0.9274
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7761
# Precision: 0.8140
# Recall: 0.8333
# F1 Score: 0.8235
# ROC AUC: 0.8138
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8600
# Recall: 0.8431
# F1 Score: 0.8515
# ROC AUC: 0.8048
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.7667025862068966, 0.7165948275862069, 0.7350848385331143, 0.7654625068418173, 0.7421875]
# Mean ROC AUC: 0.745206451833607
# ==================================================
# Train Metrics:
# Accuracy: 0.8420
# Precision: 0.9125
# Recall: 0.8522
# F1 Score: 0.8813
# ROC AUC: 0.9274
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7761
# Precision: 0.8140
# Recall: 0.8333
# F1 Score: 0.8235
# ROC AUC: 0.8138
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8600
# Recall: 0.8431
# F1 Score: 0.8515
# ROC AUC: 0.8048
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 100}
# ==================================================
# Train Metrics:
# Accuracy: 0.8442
# Precision: 0.9155
# Recall: 0.8522
# F1 Score: 0.8827
# ROC AUC: 0.9140
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7612
# Precision: 0.8095
# Recall: 0.8095
# F1 Score: 0.8095
# ROC AUC: 0.8452
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8000
# Precision: 0.8776
# Recall: 0.8431
# F1 Score: 0.8600
# ROC AUC: 0.8185
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.6144935344827587, 0.6896551724137931, 0.7334428024083197, 0.6206896551724138, 0.6194196428571428]
# Mean ROC AUC: 0.6555401614668857
# ==================================================
# Train Metrics:
# Accuracy: 0.7944
# Precision: 0.7740
# Recall: 0.9906
# F1 Score: 0.8690
# ROC AUC: 0.8953
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7015
# Precision: 0.6833
# Recall: 0.9762
# F1 Score: 0.8039
# ROC AUC: 0.8233
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7714
# Precision: 0.7612
# Recall: 1.0000
# F1 Score: 0.8644
# ROC AUC: 0.7842
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
# ==================================================
# Train Metrics:
# Accuracy: 0.8485
# Precision: 0.8263
# Recall: 0.9874
# F1 Score: 0.8997
# ROC AUC: 0.9540
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7612
# Precision: 0.7407
# Recall: 0.9524
# F1 Score: 0.8333
# ROC AUC: 0.7957
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7714
# Precision: 0.7652
# Recall: 0.9902
# F1 Score: 0.8632
# ROC AUC: 0.8224
# ==================================================
#
# Oversampled
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.8113
# Precision: 0.8113
# Recall: 0.8113
# F1 Score: 0.8113
# ROC AUC: 0.8977
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7612
# Precision: 0.8095
# Recall: 0.8095
# F1 Score: 0.8095
# ROC AUC: 0.7738
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7571
# Precision: 0.8469
# Recall: 0.8137
# F1 Score: 0.8300
# ROC AUC: 0.7625
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.8585
# Precision: 0.8677
# Recall: 0.8459
# F1 Score: 0.8567
# ROC AUC: 0.9294
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7761
# Precision: 0.8293
# Recall: 0.8095
# F1 Score: 0.8193
# ROC AUC: 0.7995
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8000
# Precision: 0.8700
# Recall: 0.8529
# F1 Score: 0.8614
# ROC AUC: 0.7899
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.8203125, 0.8111359126984127, 0.7563244047619048, 0.7560763888888888, 0.7876984126984127]
# Mean ROC AUC: 0.7863095238095237
# ==================================================
# Train Metrics:
# Accuracy: 0.8585
# Precision: 0.8677
# Recall: 0.8459
# F1 Score: 0.8567
# ROC AUC: 0.9294
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7761
# Precision: 0.8293
# Recall: 0.8095
# F1 Score: 0.8193
# ROC AUC: 0.7995
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8000
# Precision: 0.8700
# Recall: 0.8529
# F1 Score: 0.8614
# ROC AUC: 0.7899
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# ==================================================
# Train Metrics:
# Accuracy: 0.9009
# Precision: 0.9180
# Recall: 0.8805
# F1 Score: 0.8989
# ROC AUC: 0.9716
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.8409
# Recall: 0.8810
# F1 Score: 0.8605
# ROC AUC: 0.7986
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7929
# Precision: 0.8687
# Recall: 0.8431
# F1 Score: 0.8557
# ROC AUC: 0.7850
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.796875, 0.8029513888888888, 0.7563244047619048, 0.7085813492063492, 0.779513888888889]
# Mean ROC AUC: 0.7688492063492063
# ==================================================
# Train Metrics:
# Accuracy: 0.8113
# Precision: 0.8113
# Recall: 0.8113
# F1 Score: 0.8113
# ROC AUC: 0.8977
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7612
# Precision: 0.8095
# Recall: 0.8095
# F1 Score: 0.8095
# ROC AUC: 0.7738
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7571
# Precision: 0.8469
# Recall: 0.8137
# F1 Score: 0.8300
# ROC AUC: 0.7625
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# ==================================================
# Train Metrics:
# Accuracy: 0.9009
# Precision: 0.9180
# Recall: 0.8805
# F1 Score: 0.8989
# ROC AUC: 0.9716
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.8409
# Recall: 0.8810
# F1 Score: 0.8605
# ROC AUC: 0.7986
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7929
# Precision: 0.8687
# Recall: 0.8431
# F1 Score: 0.8557
# ROC AUC: 0.7850
# ==================================================
#
# SMOTE
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.8365
# Precision: 0.8408
# Recall: 0.8302
# F1 Score: 0.8354
# ROC AUC: 0.9216
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7612
# Precision: 0.8095
# Recall: 0.8095
# F1 Score: 0.8095
# ROC AUC: 0.8300
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7643
# Precision: 0.8557
# Recall: 0.8137
# F1 Score: 0.8342
# ROC AUC: 0.7945
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.8601
# Precision: 0.8682
# Recall: 0.8491
# F1 Score: 0.8585
# ROC AUC: 0.9426
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7463
# Precision: 0.7907
# Recall: 0.8095
# F1 Score: 0.8000
# ROC AUC: 0.8367
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8600
# Recall: 0.8431
# F1 Score: 0.8515
# ROC AUC: 0.8048
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.84375, 0.8267609126984127, 0.8188244047619049, 0.755828373015873, 0.7955109126984127]
# Mean ROC AUC: 0.8081349206349205
# ==================================================
# Train Metrics:
# Accuracy: 0.8601
# Precision: 0.8682
# Recall: 0.8491
# F1 Score: 0.8585
# ROC AUC: 0.9426
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7463
# Precision: 0.7907
# Recall: 0.8095
# F1 Score: 0.8000
# ROC AUC: 0.8367
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8600
# Recall: 0.8431
# F1 Score: 0.8515
# ROC AUC: 0.8048
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# ==================================================
# Train Metrics:
# Accuracy: 0.9151
# Precision: 0.9314
# Recall: 0.8962
# F1 Score: 0.9135
# ROC AUC: 0.9725
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7761
# Precision: 0.8293
# Recall: 0.8095
# F1 Score: 0.8193
# ROC AUC: 0.8300
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8600
# Recall: 0.8431
# F1 Score: 0.8515
# ROC AUC: 0.8043
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.8203125, 0.8265128968253967, 0.8266369047619047, 0.7165178571428571, 0.7874503968253969]
# Mean ROC AUC: 0.7954861111111111
# ==================================================
# Train Metrics:
# Accuracy: 0.8365
# Precision: 0.8408
# Recall: 0.8302
# F1 Score: 0.8354
# ROC AUC: 0.9216
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7612
# Precision: 0.8095
# Recall: 0.8095
# F1 Score: 0.8095
# ROC AUC: 0.8300
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7643
# Precision: 0.8557
# Recall: 0.8137
# F1 Score: 0.8342
# ROC AUC: 0.7945
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# ==================================================
# Train Metrics:
# Accuracy: 0.9151
# Precision: 0.9314
# Recall: 0.8962
# F1 Score: 0.9135
# ROC AUC: 0.9725
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7761
# Precision: 0.8293
# Recall: 0.8095
# F1 Score: 0.8193
# ROC AUC: 0.8300
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8600
# Recall: 0.8431
# F1 Score: 0.8515
# ROC AUC: 0.8043
# ==================================================
#
# Hybrid
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9443
# Precision: 0.9554
# Recall: 0.9036
# F1 Score: 0.9288
# ROC AUC: 0.9888
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7164
# Precision: 0.8966
# Recall: 0.6190
# F1 Score: 0.7324
# ROC AUC: 0.8367
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.6857
# Precision: 0.8718
# Recall: 0.6667
# F1 Score: 0.7556
# ROC AUC: 0.8017
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9685
# Precision: 0.9581
# Recall: 0.9639
# F1 Score: 0.9610
# ROC AUC: 0.9961
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7612
# Precision: 0.8421
# Recall: 0.7619
# F1 Score: 0.8000
# ROC AUC: 0.8376
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7643
# Precision: 0.8791
# Recall: 0.7843
# F1 Score: 0.8290
# ROC AUC: 0.8162
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.9296969696969698, 0.9096969696969698, 0.9252701080432173, 0.9848484848484849, 0.9038342609771182]
# Mean ROC AUC: 0.9306693586525521
# ==================================================
# Train Metrics:
# Accuracy: 0.9685
# Precision: 0.9581
# Recall: 0.9639
# F1 Score: 0.9610
# ROC AUC: 0.9961
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7612
# Precision: 0.8421
# Recall: 0.7619
# F1 Score: 0.8000
# ROC AUC: 0.8376
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7643
# Precision: 0.8791
# Recall: 0.7843
# F1 Score: 0.8290
# ROC AUC: 0.8162
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# ==================================================
# Train Metrics:
# Accuracy: 0.9879
# Precision: 0.9939
# Recall: 0.9759
# F1 Score: 0.9848
# ROC AUC: 0.9998
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7313
# Precision: 0.8333
# Recall: 0.7143
# F1 Score: 0.7692
# ROC AUC: 0.8367
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7500
# Precision: 0.8764
# Recall: 0.7647
# F1 Score: 0.8168
# ROC AUC: 0.8216
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.9245454545454544, 0.8893939393939395, 0.9252701080432173, 0.9696969696969697, 0.8735312306740877]
# Mean ROC AUC: 0.9164875404707338
# ==================================================
# Train Metrics:
# Accuracy: 0.9443
# Precision: 0.9554
# Recall: 0.9036
# F1 Score: 0.9288
# ROC AUC: 0.9888
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7164
# Precision: 0.8966
# Recall: 0.6190
# F1 Score: 0.7324
# ROC AUC: 0.8367
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.6857
# Precision: 0.8718
# Recall: 0.6667
# F1 Score: 0.7556
# ROC AUC: 0.8017
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# ==================================================
# Train Metrics:
# Accuracy: 0.9903
# Precision: 1.0000
# Recall: 0.9759
# F1 Score: 0.9878
# ROC AUC: 0.9997
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7015
# Precision: 0.9231
# Recall: 0.5714
# F1 Score: 0.7059
# ROC AUC: 0.8481
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7214
# Precision: 0.8987
# Recall: 0.6961
# F1 Score: 0.7845
# ROC AUC: 0.8180
# ==================================================

# %%
# Train on XGBoost
for train_set_name, (X_train_set, y_train_set) in train_sets.items():
    print(train_set_name)
    for config in configs:
        print(config.items())
        erg2d_model, erg2d_model_result = train_xgboost_cv(
            X_train_set, y_train_set, X_test, y_test, X_val, y_val,
            class_weight=config["class_weight"],
            use_stratified_kfold=config["use_stratified_kfold"],
            use_gridsearch=config["use_gridsearch"]
        )
        erg2d_model_results[erg2d_model] = erg2d_model_result
    print()
# Out:
# Original Set
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9697
# Precision: 0.9663
# Recall: 0.9906
# F1 Score: 0.9783
# ROC AUC: 0.9966
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7015
# Precision: 0.7200
# Recall: 0.8571
# F1 Score: 0.7826
# ROC AUC: 0.6757
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7929
# Precision: 0.8017
# Recall: 0.9510
# F1 Score: 0.8700
# ROC AUC: 0.7852
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9524
# Precision: 0.9868
# Recall: 0.9434
# F1 Score: 0.9646
# ROC AUC: 0.9937
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.6716
# Precision: 0.7500
# Recall: 0.7143
# F1 Score: 0.7317
# ROC AUC: 0.6833
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8273
# Recall: 0.8922
# F1 Score: 0.8585
# ROC AUC: 0.7847
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.7667025862068966, 0.7071659482758621, 0.7933771209633278, 0.7244116037219485, 0.7857142857142857]
# Mean ROC AUC: 0.7554743089764642
# ==================================================
# Train Metrics:
# Accuracy: 0.9524
# Precision: 0.9868
# Recall: 0.9434
# F1 Score: 0.9646
# ROC AUC: 0.9937
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.6716
# Precision: 0.7500
# Recall: 0.7143
# F1 Score: 0.7317
# ROC AUC: 0.6833
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8273
# Recall: 0.8922
# F1 Score: 0.8585
# ROC AUC: 0.7847
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.8593
# Precision: 0.9231
# Recall: 0.8679
# F1 Score: 0.8947
# ROC AUC: 0.9396
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7164
# Precision: 0.8108
# Recall: 0.7143
# F1 Score: 0.7595
# ROC AUC: 0.7576
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7714
# Precision: 0.8723
# Recall: 0.8039
# F1 Score: 0.8367
# ROC AUC: 0.7999
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.7540409482758621, 0.7273706896551724, 0.789272030651341, 0.7561576354679803, 0.7845982142857143]
# Mean ROC AUC: 0.762287903667214
# ==================================================
# Train Metrics:
# Accuracy: 0.9697
# Precision: 0.9663
# Recall: 0.9906
# F1 Score: 0.9783
# ROC AUC: 0.9966
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7015
# Precision: 0.7200
# Recall: 0.8571
# F1 Score: 0.7826
# ROC AUC: 0.6757
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7929
# Precision: 0.8017
# Recall: 0.9510
# F1 Score: 0.8700
# ROC AUC: 0.7852
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 5, 'n_estimators': 200, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.8680
# Precision: 0.8599
# Recall: 0.9654
# F1 Score: 0.9096
# ROC AUC: 0.9510
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7463
# Precision: 0.7273
# Recall: 0.9524
# F1 Score: 0.8247
# ROC AUC: 0.7519
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7786
# Precision: 0.8381
# Recall: 0.8627
# F1 Score: 0.8502
# ROC AUC: 0.8084
# ==================================================
#
# Oversampled
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9733
# Precision: 0.9748
# Recall: 0.9717
# F1 Score: 0.9732
# ROC AUC: 0.9978
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7463
# Precision: 0.7660
# Recall: 0.8571
# F1 Score: 0.8090
# ROC AUC: 0.7005
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8571
# Recall: 0.8824
# F1 Score: 0.8696
# ROC AUC: 0.7999
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9843
# Precision: 0.9783
# Recall: 0.9906
# F1 Score: 0.9844
# ROC AUC: 0.9988
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.6567
# Precision: 0.7317
# Recall: 0.7143
# F1 Score: 0.7229
# ROC AUC: 0.6843
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8000
# Precision: 0.8083
# Recall: 0.9510
# F1 Score: 0.8739
# ROC AUC: 0.7824
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.9453125, 0.9289434523809523, 0.8815724206349207, 0.8818204365079365, 0.8510664682539683]
# Mean ROC AUC: 0.8977430555555556
# ==================================================
# Train Metrics:
# Accuracy: 0.9843
# Precision: 0.9783
# Recall: 0.9906
# F1 Score: 0.9844
# ROC AUC: 0.9988
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.6567
# Precision: 0.7317
# Recall: 0.7143
# F1 Score: 0.7229
# ROC AUC: 0.6843
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8000
# Precision: 0.8083
# Recall: 0.9510
# F1 Score: 0.8739
# ROC AUC: 0.7824
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 300, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.9638
# Precision: 0.9567
# Recall: 0.9717
# F1 Score: 0.9641
# ROC AUC: 0.9951
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7612
# Precision: 0.8250
# Recall: 0.7857
# F1 Score: 0.8049
# ROC AUC: 0.7490
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7929
# Precision: 0.8687
# Recall: 0.8431
# F1 Score: 0.8557
# ROC AUC: 0.8059
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.9375, 0.9210069444444444, 0.8973214285714286, 0.8661954365079365, 0.8271329365079365]
# Mean ROC AUC: 0.8898313492063492
# ==================================================
# Train Metrics:
# Accuracy: 0.9733
# Precision: 0.9748
# Recall: 0.9717
# F1 Score: 0.9732
# ROC AUC: 0.9978
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7463
# Precision: 0.7660
# Recall: 0.8571
# F1 Score: 0.8090
# ROC AUC: 0.7005
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8571
# Recall: 0.8824
# F1 Score: 0.8696
# ROC AUC: 0.7999
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 300, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.9638
# Precision: 0.9567
# Recall: 0.9717
# F1 Score: 0.9641
# ROC AUC: 0.9951
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7612
# Precision: 0.8250
# Recall: 0.7857
# F1 Score: 0.8049
# ROC AUC: 0.7490
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7929
# Precision: 0.8687
# Recall: 0.8431
# F1 Score: 0.8557
# ROC AUC: 0.8059
# ==================================================
#
# SMOTE
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9811
# Precision: 0.9781
# Recall: 0.9843
# F1 Score: 0.9812
# ROC AUC: 0.9985
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7164
# Precision: 0.7447
# Recall: 0.8333
# F1 Score: 0.7865
# ROC AUC: 0.6748
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7643
# Precision: 0.8000
# Recall: 0.9020
# F1 Score: 0.8479
# ROC AUC: 0.7705
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9858
# Precision: 0.9783
# Recall: 0.9937
# F1 Score: 0.9860
# ROC AUC: 0.9992
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.6716
# Precision: 0.7273
# Recall: 0.7619
# F1 Score: 0.7442
# ROC AUC: 0.6824
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8214
# Recall: 0.9020
# F1 Score: 0.8598
# ROC AUC: 0.7886
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.9140625, 0.8741319444444444, 0.8821924603174602, 0.8660714285714286, 0.8193204365079365]
# Mean ROC AUC: 0.871155753968254
# ==================================================
# Train Metrics:
# Accuracy: 0.9858
# Precision: 0.9783
# Recall: 0.9937
# F1 Score: 0.9860
# ROC AUC: 0.9992
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.6716
# Precision: 0.7273
# Recall: 0.7619
# F1 Score: 0.7442
# ROC AUC: 0.6824
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8214
# Recall: 0.9020
# F1 Score: 0.8598
# ROC AUC: 0.7886
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 300, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.9654
# Precision: 0.9744
# Recall: 0.9560
# F1 Score: 0.9651
# ROC AUC: 0.9954
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7313
# Precision: 0.7857
# Recall: 0.7857
# F1 Score: 0.7857
# ROC AUC: 0.7671
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8830
# Recall: 0.8137
# F1 Score: 0.8469
# ROC AUC: 0.7914
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.90625, 0.8660714285714286, 0.8741319444444444, 0.8661954365079365, 0.8194444444444443]
# Mean ROC AUC: 0.8664186507936508
# ==================================================
# Train Metrics:
# Accuracy: 0.9811
# Precision: 0.9781
# Recall: 0.9843
# F1 Score: 0.9812
# ROC AUC: 0.9985
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7164
# Precision: 0.7447
# Recall: 0.8333
# F1 Score: 0.7865
# ROC AUC: 0.6748
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7643
# Precision: 0.8000
# Recall: 0.9020
# F1 Score: 0.8479
# ROC AUC: 0.7705
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 300, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.9654
# Precision: 0.9744
# Recall: 0.9560
# F1 Score: 0.9651
# ROC AUC: 0.9954
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7313
# Precision: 0.7857
# Recall: 0.7857
# F1 Score: 0.7857
# ROC AUC: 0.7671
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8830
# Recall: 0.8137
# F1 Score: 0.8469
# ROC AUC: 0.7914
# ==================================================
#
# Hybrid
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9976
# Precision: 0.9940
# Recall: 1.0000
# F1 Score: 0.9970
# ROC AUC: 1.0000
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.6567
# Precision: 0.7879
# Recall: 0.6190
# F1 Score: 0.6933
# ROC AUC: 0.7757
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7286
# Precision: 0.8810
# Recall: 0.7255
# F1 Score: 0.7957
# ROC AUC: 0.7721
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# ROC AUC: 1.0000
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.6567
# Precision: 0.7879
# Recall: 0.6190
# F1 Score: 0.6933
# ROC AUC: 0.7643
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7429
# Precision: 0.8929
# Recall: 0.7353
# F1 Score: 0.8065
# ROC AUC: 0.7798
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.9748484848484847, 0.9348484848484848, 0.9648859543817527, 0.9443413729128015, 0.9291898577612864]
# Mean ROC AUC: 0.949622830950562
# ==================================================
# Train Metrics:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# ROC AUC: 1.0000
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.6567
# Precision: 0.7879
# Recall: 0.6190
# F1 Score: 0.6933
# ROC AUC: 0.7643
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7429
# Precision: 0.8929
# Recall: 0.7353
# F1 Score: 0.8065
# ROC AUC: 0.7798
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 100, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.9927
# Precision: 0.9822
# Recall: 1.0000
# F1 Score: 0.9910
# ROC AUC: 0.9994
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7463
# Precision: 0.8571
# Recall: 0.7143
# F1 Score: 0.7792
# ROC AUC: 0.8138
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7714
# Precision: 0.8804
# Recall: 0.7941
# F1 Score: 0.8351
# ROC AUC: 0.7732
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.9748484848484847, 0.9348484848484848, 0.9750900360144057, 0.9443413729128015, 0.9291898577612864]
# Mean ROC AUC: 0.9516636472770926
# ==================================================
# Train Metrics:
# Accuracy: 0.9976
# Precision: 0.9940
# Recall: 1.0000
# F1 Score: 0.9970
# ROC AUC: 1.0000
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.6567
# Precision: 0.7879
# Recall: 0.6190
# F1 Score: 0.6933
# ROC AUC: 0.7757
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7286
# Precision: 0.8810
# Recall: 0.7255
# F1 Score: 0.7957
# ROC AUC: 0.7721
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 100, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.9927
# Precision: 0.9880
# Recall: 0.9940
# F1 Score: 0.9910
# ROC AUC: 0.9996
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7164
# Precision: 0.8710
# Recall: 0.6429
# F1 Score: 0.7397
# ROC AUC: 0.8129
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.6857
# Precision: 0.8718
# Recall: 0.6667
# F1 Score: 0.7556
# ROC AUC: 0.7697
# ==================================================

# %%
evaluate_model(erg2d_model_results, graph_title = "ERG 2D Featurized Dataset", Featurizer = model_name)
# Out:
# Best Model: RandomForestClassifier(max_depth=5, min_samples_split=10, n_estimators=300,
#                        n_jobs=-1, random_state=42)
# Best ROC-Score: 0.8223684210526315

# %% [markdown]
# #### Modelling (DrugTax Featuriser)

# %%
model_name = 'eos24ci'  
(X_train, y_train, X_test, y_test, 
 X_val, y_val, X_train_smote, y_train_smote, 
 X_train_over, y_train_over, X_train_hybrid, y_train_hybrid)= preprocess_and_resample(model_name)
train_sets, configs = model_config()

# %%
# Train on RandomForest
drugtax_model_results = {}
for train_set_name, (X_train_set, y_train_set) in train_sets.items():
    print(train_set_name)
    for config in configs:
        print(config.items())
        drugtax_model, drugtax_model_result = train_randomforest_cv(
            X_train_set, y_train_set, X_test, y_test, X_val, y_val,
            class_weight=config["class_weight"],
            use_stratified_kfold=config["use_stratified_kfold"],
            use_gridsearch=config["use_gridsearch"]
        )
        drugtax_model_results[drugtax_model] = drugtax_model_result
    print()
# Out:
# Original Set
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.8048
# Precision: 0.7879
# Recall: 0.9811
# F1 Score: 0.8739
# ROC AUC: 0.8738
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.6866
# Precision: 0.6780
# Recall: 0.9524
# F1 Score: 0.7921
# ROC AUC: 0.8724
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7643
# Precision: 0.7594
# Recall: 0.9902
# F1 Score: 0.8596
# ROC AUC: 0.7430
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.8395
# Precision: 0.8910
# Recall: 0.8742
# F1 Score: 0.8825
# ROC AUC: 0.8934
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8060
# Precision: 0.8537
# Recall: 0.8333
# F1 Score: 0.8434
# ROC AUC: 0.8743
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8151
# Recall: 0.9510
# F1 Score: 0.8778
# ROC AUC: 0.7730
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.7995689655172414, 0.7468527640941435, 0.7216748768472907, 0.7611607142857143, 0.8069196428571429]
# Mean ROC AUC: 0.7672353927203066
# ==================================================
# Train Metrics:
# Accuracy: 0.8395
# Precision: 0.8910
# Recall: 0.8742
# F1 Score: 0.8825
# ROC AUC: 0.8934
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8060
# Precision: 0.8537
# Recall: 0.8333
# F1 Score: 0.8434
# ROC AUC: 0.8743
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8151
# Recall: 0.9510
# F1 Score: 0.8778
# ROC AUC: 0.7730
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 300}
# ==================================================
# Train Metrics:
# Accuracy: 0.8438
# Precision: 0.8917
# Recall: 0.8805
# F1 Score: 0.8861
# ROC AUC: 0.9071
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.8750
# Recall: 0.8333
# F1 Score: 0.8537
# ROC AUC: 0.8876
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8151
# Recall: 0.9510
# F1 Score: 0.8778
# ROC AUC: 0.7632
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.6818426724137931, 0.6737821565407773, 0.6392993979200876, 0.6752232142857143, 0.6752232142857143]
# Mean ROC AUC: 0.6690741310892173
# ==================================================
# Train Metrics:
# Accuracy: 0.8048
# Precision: 0.7879
# Recall: 0.9811
# F1 Score: 0.8739
# ROC AUC: 0.8738
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.6866
# Precision: 0.6780
# Recall: 0.9524
# F1 Score: 0.7921
# ROC AUC: 0.8724
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7643
# Precision: 0.7594
# Recall: 0.9902
# F1 Score: 0.8596
# ROC AUC: 0.7430
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 300}
# ==================================================
# Train Metrics:
# Accuracy: 0.8525
# Precision: 0.8397
# Recall: 0.9717
# F1 Score: 0.9009
# ROC AUC: 0.8995
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7612
# Precision: 0.7407
# Recall: 0.9524
# F1 Score: 0.8333
# ROC AUC: 0.8805
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7929
# Precision: 0.7829
# Recall: 0.9902
# F1 Score: 0.8745
# ROC AUC: 0.7580
# ==================================================
#
# Oversampled
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.8097
# Precision: 0.7759
# Recall: 0.8711
# F1 Score: 0.8207
# ROC AUC: 0.8827
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7761
# Precision: 0.8140
# Recall: 0.8333
# F1 Score: 0.8235
# ROC AUC: 0.8857
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8000
# Precision: 0.8136
# Recall: 0.9412
# F1 Score: 0.8727
# ROC AUC: 0.7459
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.8223
# Precision: 0.7904
# Recall: 0.8774
# F1 Score: 0.8316
# ROC AUC: 0.8996
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8333
# Recall: 0.8333
# F1 Score: 0.8333
# ROC AUC: 0.8810
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8151
# Recall: 0.9510
# F1 Score: 0.8778
# ROC AUC: 0.7673
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.828125, 0.7803819444444444, 0.7797619047619048, 0.7947668650793651, 0.7869543650793651]
# Mean ROC AUC: 0.7939980158730159
# ==================================================
# Train Metrics:
# Accuracy: 0.8223
# Precision: 0.7904
# Recall: 0.8774
# F1 Score: 0.8316
# ROC AUC: 0.8996
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8333
# Recall: 0.8333
# F1 Score: 0.8333
# ROC AUC: 0.8810
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8151
# Recall: 0.9510
# F1 Score: 0.8778
# ROC AUC: 0.7673
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# ==================================================
# Train Metrics:
# Accuracy: 0.8758
# Precision: 0.8347
# Recall: 0.9371
# F1 Score: 0.8830
# ROC AUC: 0.9386
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8182
# Recall: 0.8571
# F1 Score: 0.8372
# ROC AUC: 0.8748
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8143
# Precision: 0.8167
# Recall: 0.9608
# F1 Score: 0.8829
# ROC AUC: 0.7389
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.8125, 0.7881944444444444, 0.7797619047619048, 0.7710813492063491, 0.7631448412698413]
# Mean ROC AUC: 0.782936507936508
# ==================================================
# Train Metrics:
# Accuracy: 0.8097
# Precision: 0.7759
# Recall: 0.8711
# F1 Score: 0.8207
# ROC AUC: 0.8827
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7761
# Precision: 0.8140
# Recall: 0.8333
# F1 Score: 0.8235
# ROC AUC: 0.8857
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8000
# Precision: 0.8136
# Recall: 0.9412
# F1 Score: 0.8727
# ROC AUC: 0.7459
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# ==================================================
# Train Metrics:
# Accuracy: 0.8758
# Precision: 0.8347
# Recall: 0.9371
# F1 Score: 0.8830
# ROC AUC: 0.9386
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8182
# Recall: 0.8571
# F1 Score: 0.8372
# ROC AUC: 0.8748
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8143
# Precision: 0.8167
# Recall: 0.9608
# F1 Score: 0.8829
# ROC AUC: 0.7389
# ==================================================
#
# SMOTE
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.8239
# Precision: 0.8012
# Recall: 0.8616
# F1 Score: 0.8303
# ROC AUC: 0.8983
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.8750
# Recall: 0.8333
# F1 Score: 0.8537
# ROC AUC: 0.9029
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8151
# Recall: 0.9510
# F1 Score: 0.8778
# ROC AUC: 0.7606
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.8365
# Precision: 0.8075
# Recall: 0.8836
# F1 Score: 0.8438
# ROC AUC: 0.9171
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8333
# Recall: 0.8333
# F1 Score: 0.8333
# ROC AUC: 0.8943
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8151
# Recall: 0.9510
# F1 Score: 0.8778
# ROC AUC: 0.7655
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.8203125, 0.7960069444444444, 0.8030753968253967, 0.8024553571428572, 0.8346974206349207]
# Mean ROC AUC: 0.8113095238095237
# ==================================================
# Train Metrics:
# Accuracy: 0.8365
# Precision: 0.8075
# Recall: 0.8836
# F1 Score: 0.8438
# ROC AUC: 0.9171
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8333
# Recall: 0.8333
# F1 Score: 0.8333
# ROC AUC: 0.8943
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8151
# Recall: 0.9510
# F1 Score: 0.8778
# ROC AUC: 0.7655
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# ==================================================
# Train Metrics:
# Accuracy: 0.8789
# Precision: 0.8453
# Recall: 0.9277
# F1 Score: 0.8846
# ROC AUC: 0.9468
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8043
# Recall: 0.8810
# F1 Score: 0.8409
# ROC AUC: 0.8848
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8143
# Precision: 0.8167
# Recall: 0.9608
# F1 Score: 0.8829
# ROC AUC: 0.7606
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.78125, 0.7881944444444444, 0.8030753968253967, 0.7868303571428571, 0.8503224206349207]
# Mean ROC AUC: 0.8019345238095237
# ==================================================
# Train Metrics:
# Accuracy: 0.8239
# Precision: 0.8012
# Recall: 0.8616
# F1 Score: 0.8303
# ROC AUC: 0.8983
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.8750
# Recall: 0.8333
# F1 Score: 0.8537
# ROC AUC: 0.9029
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8151
# Recall: 0.9510
# F1 Score: 0.8778
# ROC AUC: 0.7606
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# ==================================================
# Train Metrics:
# Accuracy: 0.8789
# Precision: 0.8453
# Recall: 0.9277
# F1 Score: 0.8846
# ROC AUC: 0.9468
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8043
# Recall: 0.8810
# F1 Score: 0.8409
# ROC AUC: 0.8848
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8143
# Precision: 0.8167
# Recall: 0.9608
# F1 Score: 0.8829
# ROC AUC: 0.7606
# ==================================================
#
# Hybrid
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9227
# Precision: 0.8901
# Recall: 0.9419
# F1 Score: 0.9153
# ROC AUC: 0.9674
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8060
# Precision: 0.8919
# Recall: 0.7857
# F1 Score: 0.8354
# ROC AUC: 0.8752
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7786
# Precision: 0.8198
# Recall: 0.8922
# F1 Score: 0.8545
# ROC AUC: 0.7727
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9278
# Precision: 0.8871
# Recall: 0.9593
# F1 Score: 0.9218
# ROC AUC: 0.9785
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.8947
# Recall: 0.8095
# F1 Score: 0.8500
# ROC AUC: 0.8729
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8261
# Recall: 0.9314
# F1 Score: 0.8756
# ROC AUC: 0.7846
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.8990641711229945, 0.9365448504983388, 0.939202657807309, 0.9093707250341997, 0.8744870041039671]
# Mean ROC AUC: 0.9117338817133618
# ==================================================
# Train Metrics:
# Accuracy: 0.9278
# Precision: 0.8871
# Recall: 0.9593
# F1 Score: 0.9218
# ROC AUC: 0.9785
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.8947
# Recall: 0.8095
# F1 Score: 0.8500
# ROC AUC: 0.8729
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8261
# Recall: 0.9314
# F1 Score: 0.8756
# ROC AUC: 0.7846
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# ==================================================
# Train Metrics:
# Accuracy: 0.9407
# Precision: 0.9071
# Recall: 0.9651
# F1 Score: 0.9352
# ROC AUC: 0.9868
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.8947
# Recall: 0.8095
# F1 Score: 0.8500
# ROC AUC: 0.8624
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8261
# Recall: 0.9314
# F1 Score: 0.8756
# ROC AUC: 0.7644
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.910427807486631, 0.9079734219269102, 0.939202657807309, 0.8946648426812586, 0.8597811217510258]
# Mean ROC AUC: 0.902409970330627
# ==================================================
# Train Metrics:
# Accuracy: 0.9227
# Precision: 0.8901
# Recall: 0.9419
# F1 Score: 0.9153
# ROC AUC: 0.9674
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8060
# Precision: 0.8919
# Recall: 0.7857
# F1 Score: 0.8354
# ROC AUC: 0.8752
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7786
# Precision: 0.8198
# Recall: 0.8922
# F1 Score: 0.8545
# ROC AUC: 0.7727
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best Parameters from GridSearchCV: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# ==================================================
# Train Metrics:
# Accuracy: 0.9407
# Precision: 0.9116
# Recall: 0.9593
# F1 Score: 0.9348
# ROC AUC: 0.9908
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.8947
# Recall: 0.8095
# F1 Score: 0.8500
# ROC AUC: 0.8667
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8261
# Recall: 0.9314
# F1 Score: 0.8756
# ROC AUC: 0.7696
# ==================================================

# %%
# Train on XGBoost 
for train_set_name, (X_train_set, y_train_set) in train_sets.items():
    print(train_set_name)
    for config in configs:
        print(config.items())
        drugtax_model, drugtax_model_result = train_xgboost_cv(
            X_train_set, y_train_set, X_test, y_test, X_val, y_val,
            class_weight=config["class_weight"],
            use_stratified_kfold=config["use_stratified_kfold"],
            use_gridsearch=config["use_gridsearch"]
        )
        drugtax_model_results[drugtax_model] = drugtax_model_result
    print()
# Out:
# Original Set
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9154
# Precision: 0.9115
# Recall: 0.9717
# F1 Score: 0.9406
# ROC AUC: 0.9591
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7463
# Precision: 0.7907
# Recall: 0.8095
# F1 Score: 0.8000
# ROC AUC: 0.8314
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7929
# Precision: 0.8017
# Recall: 0.9510
# F1 Score: 0.8700
# ROC AUC: 0.7789
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.8503
# Precision: 0.9220
# Recall: 0.8553
# F1 Score: 0.8874
# ROC AUC: 0.9502
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.9167
# Recall: 0.7857
# F1 Score: 0.8462
# ROC AUC: 0.8248
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7500
# Precision: 0.8190
# Recall: 0.8431
# F1 Score: 0.8309
# ROC AUC: 0.7784
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.8529094827586207, 0.7309797482211275, 0.672687465790914, 0.7935267857142857, 0.765625]
# Mean ROC AUC: 0.7631456964969896
# ==================================================
# Train Metrics:
# Accuracy: 0.8503
# Precision: 0.9220
# Recall: 0.8553
# F1 Score: 0.8874
# ROC AUC: 0.9502
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.9167
# Recall: 0.7857
# F1 Score: 0.8462
# ROC AUC: 0.8248
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7500
# Precision: 0.8190
# Recall: 0.8431
# F1 Score: 0.8309
# ROC AUC: 0.7784
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 300, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.8872
# Precision: 0.9236
# Recall: 0.9119
# F1 Score: 0.9177
# ROC AUC: 0.9605
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8060
# Precision: 0.8718
# Recall: 0.8095
# F1 Score: 0.8395
# ROC AUC: 0.8352
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7857
# Precision: 0.8051
# Recall: 0.9314
# F1 Score: 0.8636
# ROC AUC: 0.7786
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.7618534482758622, 0.7441160372194855, 0.6699507389162562, 0.7790178571428572, 0.7790178571428572]
# Mean ROC AUC: 0.7467911877394637
# ==================================================
# Train Metrics:
# Accuracy: 0.9154
# Precision: 0.9115
# Recall: 0.9717
# F1 Score: 0.9406
# ROC AUC: 0.9591
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7463
# Precision: 0.7907
# Recall: 0.8095
# F1 Score: 0.8000
# ROC AUC: 0.8314
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7929
# Precision: 0.8017
# Recall: 0.9510
# F1 Score: 0.8700
# ROC AUC: 0.7789
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 200, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.8937
# Precision: 0.8810
# Recall: 0.9780
# F1 Score: 0.9270
# ROC AUC: 0.9566
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7313
# Precision: 0.7400
# Recall: 0.8810
# F1 Score: 0.8043
# ROC AUC: 0.8324
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8000
# Precision: 0.7984
# Recall: 0.9706
# F1 Score: 0.8761
# ROC AUC: 0.7843
# ==================================================
#
# Oversampled
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9261
# Precision: 0.9357
# Recall: 0.9151
# F1 Score: 0.9253
# ROC AUC: 0.9750
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.8947
# Recall: 0.8095
# F1 Score: 0.8500
# ROC AUC: 0.8143
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7571
# Precision: 0.7931
# Recall: 0.9020
# F1 Score: 0.8440
# ROC AUC: 0.7771
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9465
# Precision: 0.9522
# Recall: 0.9403
# F1 Score: 0.9462
# ROC AUC: 0.9845
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8358
# Precision: 0.9189
# Recall: 0.8095
# F1 Score: 0.8608
# ROC AUC: 0.8162
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7500
# Precision: 0.7913
# Recall: 0.8922
# F1 Score: 0.8387
# ROC AUC: 0.7546
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.859375, 0.8743799603174602, 0.8736359126984127, 0.8421378968253969, 0.8270089285714287]
# Mean ROC AUC: 0.8553075396825397
# ==================================================
# Train Metrics:
# Accuracy: 0.9465
# Precision: 0.9522
# Recall: 0.9403
# F1 Score: 0.9462
# ROC AUC: 0.9845
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8358
# Precision: 0.9189
# Recall: 0.8095
# F1 Score: 0.8608
# ROC AUC: 0.8162
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7500
# Precision: 0.7913
# Recall: 0.8922
# F1 Score: 0.8387
# ROC AUC: 0.7546
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 300, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.9167
# Precision: 0.8909
# Recall: 0.9497
# F1 Score: 0.9193
# ROC AUC: 0.9779
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8500
# Recall: 0.8095
# F1 Score: 0.8293
# ROC AUC: 0.8067
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7714
# Precision: 0.8070
# Recall: 0.9020
# F1 Score: 0.8519
# ROC AUC: 0.7526
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.859375, 0.8665674603174602, 0.8658234126984127, 0.8501984126984126, 0.8506944444444443]
# Mean ROC AUC: 0.8585317460317461
# ==================================================
# Train Metrics:
# Accuracy: 0.9261
# Precision: 0.9357
# Recall: 0.9151
# F1 Score: 0.9253
# ROC AUC: 0.9750
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8209
# Precision: 0.8947
# Recall: 0.8095
# F1 Score: 0.8500
# ROC AUC: 0.8143
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7571
# Precision: 0.7931
# Recall: 0.9020
# F1 Score: 0.8440
# ROC AUC: 0.7771
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 300, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.9167
# Precision: 0.8909
# Recall: 0.9497
# F1 Score: 0.9193
# ROC AUC: 0.9779
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8500
# Recall: 0.8095
# F1 Score: 0.8293
# ROC AUC: 0.8067
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7714
# Precision: 0.8070
# Recall: 0.9020
# F1 Score: 0.8519
# ROC AUC: 0.7526
# ==================================================
#
# SMOTE
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9403
# Precision: 0.9242
# Recall: 0.9591
# F1 Score: 0.9414
# ROC AUC: 0.9858
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8060
# Precision: 0.8718
# Recall: 0.8095
# F1 Score: 0.8395
# ROC AUC: 0.8495
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8319
# Recall: 0.9216
# F1 Score: 0.8744
# ROC AUC: 0.7841
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9450
# Precision: 0.9301
# Recall: 0.9623
# F1 Score: 0.9459
# ROC AUC: 0.9918
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8684
# Recall: 0.7857
# F1 Score: 0.8250
# ROC AUC: 0.8552
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8205
# Recall: 0.9412
# F1 Score: 0.8767
# ROC AUC: 0.7838
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.8828125, 0.8509424603174602, 0.8819444444444444, 0.834201388888889, 0.8503224206349207]
# Mean ROC AUC: 0.8600446428571429
# ==================================================
# Train Metrics:
# Accuracy: 0.9450
# Precision: 0.9301
# Recall: 0.9623
# F1 Score: 0.9459
# ROC AUC: 0.9918
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8684
# Recall: 0.7857
# F1 Score: 0.8250
# ROC AUC: 0.8552
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8205
# Recall: 0.9412
# F1 Score: 0.8767
# ROC AUC: 0.7838
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 300, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.9292
# Precision: 0.9003
# Recall: 0.9654
# F1 Score: 0.9317
# ROC AUC: 0.9829
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8358
# Precision: 0.8605
# Recall: 0.8810
# F1 Score: 0.8706
# ROC AUC: 0.8476
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7786
# Precision: 0.7983
# Recall: 0.9314
# F1 Score: 0.8597
# ROC AUC: 0.7686
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.8828125, 0.8509424603174602, 0.8505704365079365, 0.834201388888889, 0.8504464285714286]
# Mean ROC AUC: 0.8537946428571429
# ==================================================
# Train Metrics:
# Accuracy: 0.9403
# Precision: 0.9242
# Recall: 0.9591
# F1 Score: 0.9414
# ROC AUC: 0.9858
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8060
# Precision: 0.8718
# Recall: 0.8095
# F1 Score: 0.8395
# ROC AUC: 0.8495
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.8071
# Precision: 0.8319
# Recall: 0.9216
# F1 Score: 0.8744
# ROC AUC: 0.7841
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 300, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.9292
# Precision: 0.9003
# Recall: 0.9654
# F1 Score: 0.9317
# ROC AUC: 0.9829
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8358
# Precision: 0.8605
# Recall: 0.8810
# F1 Score: 0.8706
# ROC AUC: 0.8476
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7786
# Precision: 0.7983
# Recall: 0.9314
# F1 Score: 0.8597
# ROC AUC: 0.7686
# ==================================================
#
# Hybrid
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9639
# Precision: 0.9702
# Recall: 0.9477
# F1 Score: 0.9588
# ROC AUC: 0.9948
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7761
# Precision: 0.8462
# Recall: 0.7857
# F1 Score: 0.8148
# ROC AUC: 0.8571
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7714
# Precision: 0.8302
# Recall: 0.8627
# F1 Score: 0.8462
# ROC AUC: 0.7748
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', False)])
# ==================================================
# Train Metrics:
# Accuracy: 0.9768
# Precision: 0.9711
# Recall: 0.9767
# F1 Score: 0.9739
# ROC AUC: 0.9970
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8684
# Recall: 0.7857
# F1 Score: 0.8250
# ROC AUC: 0.8543
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7500
# Precision: 0.8190
# Recall: 0.8431
# F1 Score: 0.8309
# ROC AUC: 0.7771
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.9364973262032086, 0.8963455149501661, 0.9740863787375416, 0.9209986320109439, 0.9124487004103967]
# Mean ROC AUC: 0.9280753104624514
# ==================================================
# Train Metrics:
# Accuracy: 0.9768
# Precision: 0.9711
# Recall: 0.9767
# F1 Score: 0.9739
# ROC AUC: 0.9970
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8684
# Recall: 0.7857
# F1 Score: 0.8250
# ROC AUC: 0.8543
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7500
# Precision: 0.8190
# Recall: 0.8431
# F1 Score: 0.8309
# ROC AUC: 0.7771
# ==================================================
# dict_items([('class_weight', True), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 300, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.9742
# Precision: 0.9551
# Recall: 0.9884
# F1 Score: 0.9714
# ROC AUC: 0.9991
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7910
# Precision: 0.8684
# Recall: 0.7857
# F1 Score: 0.8250
# ROC AUC: 0.8267
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7500
# Precision: 0.8252
# Recall: 0.8333
# F1 Score: 0.8293
# ROC AUC: 0.7781
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', True), ('use_gridsearch', False)])
#
# Cross-Validation ROC AUC Scores: [0.9364973262032086, 0.8963455149501661, 0.948172757475083, 0.9062927496580028, 0.9093707250341997]
# Mean ROC AUC: 0.9193358146641322
# ==================================================
# Train Metrics:
# Accuracy: 0.9639
# Precision: 0.9702
# Recall: 0.9477
# F1 Score: 0.9588
# ROC AUC: 0.9948
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.7761
# Precision: 0.8462
# Recall: 0.7857
# F1 Score: 0.8148
# ROC AUC: 0.8571
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7714
# Precision: 0.8302
# Recall: 0.8627
# F1 Score: 0.8462
# ROC AUC: 0.7748
# ==================================================
# dict_items([('class_weight', False), ('use_stratified_kfold', False), ('use_gridsearch', True)])
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best Parameters from GridSearchCV: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 300, 'subsample': 0.8}
# ==================================================
# Train Metrics:
# Accuracy: 0.9742
# Precision: 0.9602
# Recall: 0.9826
# F1 Score: 0.9713
# ROC AUC: 0.9986
# ==================================================
# ==================================================
# Validation Metrics:
# Accuracy: 0.8060
# Precision: 0.8919
# Recall: 0.7857
# F1 Score: 0.8354
# ROC AUC: 0.8248
# ==================================================
# ==================================================
# Test Metrics:
# Accuracy: 0.7571
# Precision: 0.8269
# Recall: 0.8431
# F1 Score: 0.8350
# ROC AUC: 0.7748
# ==================================================

# %%
evaluate_model(drugtax_model_results, graph_title = "DrugTax Featurized Dataset", Featurizer = model_name)
# Out:
# Best Model: RandomForestClassifier(class_weight={0: 0.8981481481481481,
#                                      1: 1.127906976744186},
#                        max_depth=4, min_samples_leaf=5, min_samples_split=5,
#                        n_estimators=200, n_jobs=-1, random_state=42)
# Best ROC-Score: 0.7845717234262126
